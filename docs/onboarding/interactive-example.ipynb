# %% [markdown]
# # OpenGoat Interactive Example
#
# This notebook demonstrates basic agent creation and task assignment.

# %%
# Install if needed
# !npm i -g opengoat

# Run CLI commands
# !opengoat agent list
